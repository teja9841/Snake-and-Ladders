# %% [markdown]
# # Dice

# %%
import random
def roll_a_die():
    dice=[1,2,3,4,5,6]
    random.shuffle(dice)
    return dice[0]

# %% [markdown]
# # Player info

# %%
player_1=input("Player-1 please provide your name: ")
player_2=input("Player-2 please provide your name: ")
# Out:
# Player-1 please provide your name: Teja
# Player-2 please provide your name: Varsha

# %%
            elif p2>=94:
                if p2+dye<=100:
                    p2+=dye
                else:
                    pass

# %% [markdown]
# # Game

# %%
def snake_and_ladders():
    p1=0
    p2=0

    while True:
        a=input("{} Do you want to roll the dye: Y or N --> ".format(player_1))
        if a=="Y" or a=="y":
            dye=roll_a_die()
            p1+=dye
            print("{} entered to {} in the board".format(player_1,p1))
            if p1==4:
                p1+=52
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_1,p1))
                continue
            elif p1==12:
                p1+=38
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_1,p1))
                continue
            elif p1==14:
                p1+=41
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_1,p1))
                continue
            elif p1==22:
                p1+=36
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_1,p1))
                continue
            elif p1==41:
                p1+=38
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_1,p1))
                continue
            elif p1==54:
                p1+=34
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_1,p1))
                continue
            elif p1==28:
                p1-=18
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_1,p1))
            elif p1==37:
                p1-=34
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_1,p1))
            elif p1==47:
                p1-=31
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_1,p1))
            elif p1==75:
                p1-=43
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_1,p1))
            elif p1==94:
                p1-=22
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_1,p1))
            elif p1==96:
                p1-=54
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_1,p1))
            elif p1>=100:
                print("{} won the game".format(player_1))
                print("\nGame Over")
                break
        elif a=="N" or a=="n":
            print("Do you want to quit the game?")
            print("Type Yes or No")
            a=input()
            if a=="Yes":
                break
            else:
                pass
        b=input("{} Do you want to roll the dye: Y or N --> ".format(player_2))
        if b=="Y" or b=="y":
            dye=roll_a_die()
            p2+=dye
            print("{} entered to {} in the board".format(player_2,p2))
            if p2==4:
                p2+=52
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_2,p2))
                continue
            elif p2==12:
                p2+=38
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_2,p2))
                continue
            elif p2==14:
                p2+=41
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_2,p2))
                continue
            elif p2==22:
                p2+=36
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_2,p2))
                continue
            elif p2==41:
                p2+=38
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_2,p2))
                continue
            elif p2==54:
                p2+=34
                print("hurrah! {} had climbed the LADDER and moved to {}".format(player_2,p2))
                continue
            elif p2==28:
                p2-=18
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_2,p2))
            elif p2==37:
                p2-=34
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_2,p2))
            elif p2==47:
                p2-=31
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_2,p2))
            elif p2==75:
                p2-=43
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_2,p2))
            elif p2==94:
                p2-=22
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_2,p2))
            elif p2==96:
                p2-=54
                print("Oh shit! Bad Luck, {} had bitten by Snake and moved to {}".format(player_2,p2))
            elif p2>=100:
                print("{} won the game".format(player_2))
                print("\nGame Over")
                break
        elif b=="N" or b=="n":
            print("Do you want to quit the game?")
            print("Type Yes or No")
            a=input()
            if a=="Yes":
                break
            else:
                pass

# %% [markdown]
# ![Snake-and-Ladder-Template-1.png](attachment:Snake-and-Ladder-Template-1.png)

# %%
snake_and_ladders()
# Out:
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 3 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 1 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 8 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 7 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 11 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 11 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 12 in the board
# hurrah! Teja had climbed the LADDER and moved to 50
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 54 in the board
# hurrah! Teja had climbed the LADDER and moved to 88
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 91 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 15 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 96 in the board
# Oh shit! Bad Luck, Teja had bitten by Snake and moved to 42
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 17 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 45 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 19 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 50 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 25 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 55 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 31 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 61 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 35 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 62 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 40 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 63 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 42 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 68 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 43 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 74 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 46 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 79 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 47 in the board
# Oh shit! Bad Luck, Varsha had bitten by Snake and moved to 16
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 80 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 21 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 86 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 22 in the board
# hurrah! Varsha had climbed the LADDER and moved to 58
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 92 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 62 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 95 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 64 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 98 in the board
# Varsha Do you want to roll the dye: Y or N --> y
# Varsha entered to 68 in the board
# Teja Do you want to roll the dye: Y or N --> y
# Teja entered to 101 in the board
# Teja won the game
#
# Game Over
